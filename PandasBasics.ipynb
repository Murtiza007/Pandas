# %% [markdown]
# data analysis using pandas

# %%
cars={
    'name': ['inova','i10','fortuner','camry'],
    'company': ['toyota','Hyundai','toyota','toyota'],
    'year': [2020,2019,2018,2021],
    'color': ['black','white','red','blue'],
    'price': [30000,20000,40000,50000]
}

print(cars)
# Out:
# {'name': ['inova', 'i10', 'fortuner', 'camry'], 'company': ['toyota', 'Hyundai', 'toyota', 'toyota'], 'year': [2020, 2019, 2018, 2021], 'color': ['black', 'white', 'red', 'blue'], 'price': [30000, 20000, 40000, 50000]}

# %%
#creating dataframe
import pandas as pd
data=pd.DataFrame(cars)
data
# Out:
#        name  company  year  color  price
# 0     inova   toyota  2020  black  30000
# 1       i10  Hyundai  2019  white  20000
# 2  fortuner   toyota  2018    red  40000
# 3     camry   toyota  2021   blue  50000

# %%
#inserting new column

data.insert(4,"mileage",[10,15,12,14])
data
# Out:
#        name  company  year  color  mileage  price
# 0     inova   toyota  2020  black       10  30000
# 1       i10  Hyundai  2019  white       15  20000
# 2  fortuner   toyota  2018    red       12  40000
# 3     camry   toyota  2021   blue       14  50000

# %%
#copy column
data.insert(5,"model",data["year"])
data
# Out:
#        name  company  year  color  mileage  model  price
# 0     inova   toyota  2020  black       10   2020  30000
# 1       i10  Hyundai  2019  white       15   2019  20000
# 2  fortuner   toyota  2018    red       12   2018  40000
# 3     camry   toyota  2021   blue       14   2021  50000

# %%
#delete column
#data.pop("price")
del data["color"]
data
# Out:
#        name  company  year  mileage  model
# 0     inova   toyota  2020       10   2020
# 1       i10  Hyundai  2019       15   2019
# 2  fortuner   toyota  2018       12   2018
# 3     camry   toyota  2021       14   2021

# %%
#concatination vs merging

section_APrimary={
    'name':['raj','simran','rahul'],
    'science':[90,80,70],
    'maths':[80,90,60],
    'urdu':[70,60,80]
}
section_ASecondary={
    'name':['raj','simran','rahul'],
    'history':[90,80,70],
    'geo':[80,90,60],
    'civics':[70,60,80]
}


section_BPrimary={
    'name':['moin','ahmad','basit'],
    'science':[90,80,70],
    'maths':[80,90,60],
    'urdu':[70,60,80]
}
section_BSecondary={
    'name':['moin','ahmad','basit'],
    'history':[90,80,70],
    'geo':[80,90,60],
    'civics':[70,60,80]
}
 
 # a overall
 # a & b combined
 # b overall

# %%
A_pry=pd.DataFrame(section_APrimary)
A_sec=pd.DataFrame(section_ASecondary)
B_sec=pd.DataFrame(section_BSecondary)
B_pry=pd.DataFrame(section_BPrimary)

A_pry
A_sec
# Out:
#      name  history  geo  civics
# 0     raj       90   80      70
# 1  simran       80   90      60
# 2   rahul       70   60      80

# %%
A_overall=pd.merge(A_pry,A_sec,on="name")
A_overall
# Out:
#      name  science  maths  urdu  history  geo  civics
# 0     raj       90     80    70       90   80      70
# 1  simran       80     90    60       80   90      60
# 2   rahul       70     60    80       70   60      80

# %%
B_overall=pd.merge(B_pry,B_sec,on="name")
B_overall
# Out:
#     name  science  maths  urdu  history  geo  civics
# 0   moin       90     80    70       90   80      70
# 1  ahmad       80     90    60       80   90      60
# 2  basit       70     60    80       70   60      80

# %%
sec_overall=pd.concat([A_overall,B_overall])
sec_overall
sec_overall.reset_index(inplace=True)
sec_overall
sec_overall.pop("index")
sec_overall
# Out:
#      name  science  maths  urdu  history  geo  civics
# 0     raj       90     80    70       90   80      70
# 1  simran       80     90    60       80   90      60
# 2   rahul       70     60    80       70   60      80
# 3    moin       90     80    70       90   80      70
# 4   ahmad       80     90    60       80   90      60
# 5   basit       70     60    80       70   60      80

# %%
import pandas as pd

#reading csv file
data=pd.read_csv("datasets//titanic.csv")

#analysis
#manupilation
#cleaning --- duplicates,missing values,null values,format errors

#
data.head(2)

#
data.tail()

#
data.shape

#
data.columns

data2=data.iloc[50:56]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data3=data[["Name","Age"]]
data3
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
import pandas as pd
data=pd.read_csv("datasets//titanic.csv")
data.head()
data.tail()
data.columns
data.dtypes
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# see all data
pd.set_option('display.max_rows',None)

#access
data.iloc[100:105]
data[["PassengerId","Name","Age"]]
data2=data.loc[100:105,["PassengerId","Name","Age"]]

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 26.00    18
# 35.00    18
# 27.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 34.00    15
# 33.00    15
# 39.00    14
# 42.00    13
# 17.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 2.00     10
# 50.00    10
# 4.00     10
# 48.00     9
# 47.00     9
# 44.00     9
# 54.00     8
# 9.00      8
# 51.00     7
# 1.00      7
# 37.00     6
# 14.00     6
# 52.00     6
# 41.00     6
# 49.00     6
# 3.00      6
# 58.00     5
# 15.00     5
# 43.00     5
# 5.00      4
# 8.00      4
# 11.00     4
# 56.00     4
# 60.00     4
# 62.00     4
# 61.00     3
# 6.00      3
# 46.00     3
# 65.00     3
# 7.00      3
# 13.00     2
# 55.00     2
# 70.00     2
# 57.00     2
# 30.50     2
# 32.50     2
# 71.00     2
# 40.50     2
# 59.00     2
# 0.83      2
# 28.50     2
# 10.00     2
# 0.75      2
# 64.00     2
# 63.00     2
# ...

# %%
import pandas as pd

data=pd.read_csv('datasets//titanic.csv')

# data
# pd.set_option('display.max_rows',None)
# pd.set_option('display.max_Columns',None)

data.head()
data.tail()
data.columns
data.shape
#data.info()
data.dtypes
data.describe()
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
##data["Age"].value_counts()

#accessing
data.iloc[100:105]
data[["Name","Age","Survived"]]
data.loc[100:105,["Name","Age","Survived"]]


DATA2=data[["Name","Age","Survived"]]
DATA2.iloc[100:105]
# Out:
#                                  Name   Age  Survived
# 100           Petranec, Miss. Matilda  28.0         0
# 101  Petroff, Mr. Pastcho ("Pentcho")   NaN         0
# 102         White, Mr. Richard Frasar  21.0         0
# 103        Johansson, Mr. Gustaf Joel  33.0         0
# 104    Gustafsson, Mr. Anders Vilhelm  37.0         0

# %%
#filtering
data["Sex"]=="female"

#sorting
data.sort_values(by="Pclass",ascending=False)

data_new=data.loc[100:105,["Name","Age","Survived"]]
#exporting
data_new.to_html("titanic.html")

data.to_csv("titanic_new.csv")

data6=data.groupby(["Age"])
data6.size()

# %%
#filtering
data["Pclass"]==1

#sorting
data.sort_values(by="Age",ascending=False)

data6=data.groupby(["Embarked"])
data6.size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    cat
# 0      0         A/5 21171   7.2500   NaN        S  Adult
# 1      0          PC 17599  71.2833   C85        C  Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adult
# 3      0            113803  53.1000  C123        S  Adult
# ...

# %%
data['Fare'].sum()
data['Fare'].max()
data['Fare'].max()
data['Fare'].mean()

data_age=data[data["Fare"]>100]
data_age.shape

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    cat
# 0      0         A/5 21171   7.2500   NaN        S  Adult
# 1      0          PC 17599  71.2833   C85        C  Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adult
# 3      0            113803  53.1000  C123        S  Adult
# ...

# %%
#apply

data["status"]=data["Survived"].apply(lambda x: 'survived' if x==1 else 'not survived')
data

data["class"] = data["Pclass"].apply(lambda x: 'Business' if x == 1 else ('first' if x == 2 else 'economy'))
data

data.head()
data.drop("Pclass",axis=1)

data["Age"].isnull().sum()

data.shape
data.dropna(inplace=True)
data.shape
# Out:
# (183, 15)

# %%
import pandas as pd
data=pd.read_excel("datasets//gandaData.xlsx")
pd.set_option('display.max_columns',None)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                           #Braund, Mr. Owen Harris    male  22.0      1
# 1  .Cumings, Mrs. John Bradley (Florence Briggs T...  female  38.0      1
# 2                            $Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                         Allen, Mr. William Henry>>    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0      0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1      0          PC 17599  71.2833   C85        C  woman       False    C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PassengerId     29 non-null     int64
#  1   Survived        29 non-null     int64
#  2   Pclass          29 non-null     int64
#  3   Name            29 non-null     object
#  4   Gender          29 non-null     object
#  5   Age             26 non-null     float64
#  6   SibSp           29 non-null     int64
#  7   Parch           29 non-null     int64
#  8   Ticket          29 non-null     object
#  9   Fare            29 non-null     float64
#  10  Cabin           9 non-null      object
#  11  Embarked        29 non-null     object
#  12  who             29 non-null     object
#  13  adult_male      29 non-null     bool
#  14  deck            9 non-null      object
#  15  embark_town     29 non-null     object
#  16  alive           29 non-null     object
# ...

# %%
# data.set_index(["PassengerId"],inplace=True)
data.head()
data.drop_duplicates(inplace=True)
data.shape
data.tail()
# Out:
#              Survived  Pclass  \
# PassengerId
# 13                  0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Gender   Age  \
# PassengerId
# 13                              Saundercock, Mr. William Henry    male  20.0
# 2            .Cumings, Mrs. John Bradley (Florence Briggs T...  female  38.0
# 3                                      $Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                   Allen, Mr. William Henry>>    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked    who  \
# PassengerId
# 13               0      0         A/5. 2151   8.0500   NaN        S    man
# 2                1      0          PC 17599  71.2833   C85        C  woman
# ...

# %%
data["Name"]=data["Name"].str.lstrip("# . $")
data["Name"]=data["Name"].str.rstrip("# . $ >")
data["Name"]=data["Name"].str.strip("# . $")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0      0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1      0          PC 17599  71.2833   C85        C  woman       False    C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# ...

# %%
data.drop(["Unnamed: 20"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0      0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1      0          PC 17599  71.2833   C85        C  woman       False    C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# ...

# %%
data["Do_Not_Contact"]=data["Do_Not_Contact"].str.replace('Y','Yes')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0      0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1      0          PC 17599  71.2833   C85        C  woman       False    C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# ...

# %%
# data[["street","city","zip"]]=data["Address"].str.split(",",n=2,expand=True)
# data[["Surname","FisrtName"]]=data["Name"].str.split(",",n=1,expand=True)

data.drop(["Address","city","zip","Name"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1          PC 17599  71.2833   C85        C  woman       False    C
# 2  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# 3            113803  53.1000  C123        S  woman       False    C
# 4            373450   8.0500   NaN        S    man        True  NaN
#
#    embark_town alive  alone  Phone_Number Do_Not_Contact               street  \
# 0  Southampton    no  False  123-545-5421             No       123 Shire Lane
# ...

# %%
data["Phone_Number"]=data["Phone_Number"].astype(str).replace('[^a-zA-Z0-9]','',regex=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1          PC 17599  71.2833   C85        C  woman       False    C
# 2  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# 3            113803  53.1000  C123        S  woman       False    C
# 4            373450   8.0500   NaN        S    man        True  NaN
#
#    embark_town alive  alone Phone_Number Do_Not_Contact               street  \
# 0  Southampton    no  False   1235455421             No       123 Shire Lane
# ...

# %%
data["Phone_Number"]=data["Phone_Number"].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:10])
data.head()
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 0         A/5 21171   7.2500   NaN        S    man        True  NaN
# 1          PC 17599  71.2833   C85        C  woman       False    C
# 2  STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# 3            113803  53.1000  C123        S  woman       False    C
# 4            373450   8.0500   NaN        S    man        True  NaN
#
#    embark_town alive  alone  Phone_Number Do_Not_Contact               street  \
# 0  Southampton    no  False  123-545-5421             No       123 Shire Lane
# ...

# %%
for x in data.index:
    if data.loc[x,"Do_Not_Contact"]=='Yes':
        data.drop (x,inplace=True)
        
for x in data.index:
    if data.loc[x,"alive"]=='no':
        data.drop (x,inplace=True)
        
for x in data.index:
    if data.loc[x,"Phone_Number"]=='Na--':
        data.drop (x,inplace=True)
data
# Out:
#     PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 2             3         1       3  female  26.0      0      0
# 9            10         1       2  female  14.0      1      0
# 11           12         1       1  female  58.0      0      0
# 15           16         1       2  female  55.0      0      0
# 17           18         1       2    male   NaN      0      0
# 20           10         1       2  female  14.0      1      0
# 25            2         1       1  female  38.0      1      0
# 26            3         1       3  female  26.0      0      0
# 27            4         1       1  female  35.0      1      0
#
#               Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 2   STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# 9             237736  30.0708   NaN        C  child       False  NaN
# 11            113783  26.5500  C103        S  woman       False    C
# ...

# %%
# data.shape
# data.drop_duplicates(inplace=True)

data = data.drop_duplicates(subset=['PassengerId'])
# data.shape
# data.reset_index(inplace=True)
# data.drop("index",axis=1,inplace=True)
data
# Out:
#     PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 2             3         1       3  female  26.0      0      0
# 9            10         1       2  female  14.0      1      0
# 11           12         1       1  female  58.0      0      0
# 15           16         1       2  female  55.0      0      0
# 17           18         1       2    male   NaN      0      0
# 25            2         1       1  female  38.0      1      0
# 27            4         1       1  female  35.0      1      0
#
#               Ticket     Fare Cabin Embarked    who  adult_male deck  \
# 2   STON/O2. 3101282   7.9250   NaN        S  woman       False  NaN
# 9             237736  30.0708   NaN        C  child       False  NaN
# 11            113783  26.5500  C103        S  woman       False    C
# 15            248706  16.0000   NaN        S  woman       False  NaN
# 17            244373  13.0000   NaN        S    man        True  NaN
# ...

# %%
data.shape
# Out:
# (7, 22)

# %%
#index

import pandas as pd
data=pd.read_csv("datasets//world_population.csv" ) 
data.set_index("Area (km²)",inplace=True)
data.sort_index(inplace=True,ascending=False)
data
# Out:
#             Rank CCA3 Country/Territory           Capital      Continent  \
# Area (km²)
# 17098242       9  RUS            Russia            Moscow         Europe
# 9984670       39  CAN            Canada            Ottawa  North America
# 9706961        1  CHN             China           Beijing           Asia
# 9372610        3  USA     United States  Washington, D.C.  North America
# 8515767        7  BRA            Brazil          Brasilia  South America
# ...          ...  ...               ...               ...            ...
# 21           225  NRU             Nauru             Yaren        Oceania
# 12           233  TKL           Tokelau          Nukunonu        Oceania
# 6            219  GIB         Gibraltar         Gibraltar         Europe
# 2            217  MCO            Monaco            Monaco         Europe
# 1            234  VAT      Vatican City      Vatican City         Europe
#
#             2022 Population  2020 Population  2015 Population  \
# Area (km²)
# ...

# %%
data.loc["Rome"]
# Out:
# Rank                                 25
# CCA3                                ITA
# Country/Territory                 Italy
# Continent                        Europe
# 2022 Population                59037474
# 2020 Population                59500579
# 2015 Population                60232906
# 2010 Population                59822450
# 2000 Population                56966397
# 1990 Population                56756561
# 1980 Population                56329482
# 1970 Population                53324036
# Area (km²)                       301336
# Density (per km²)              195.9191
# Growth Rate                      0.9966
# World Population Percentage        0.74
# Name: Rome, dtype: object
